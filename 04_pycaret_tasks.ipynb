# %% [markdown]
# #Работу выполнил Росляков Владислав Александрович
# # ББМО-01-23

# %% [markdown]
# #Выполните следующие задания:
# ###-Импортируйте набор данных 'diabetes'
# ###-Выполните импорт всех библиотек из модуля classification библиотеки pycaret
# ###-Настройте эксперимент, цель - значения столбца 'Class variable'
# ###-Выполните поиск наилучшей модели
# ###-Определите наиболее значимые признаки
# ###-Выполните графическое построение наилучшей модели

# %% [markdown]
# #1.Импортируйте набор данных 'diabetes'

# %%
# !pip install pycaret
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 485.9/485.9 kB 2.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.1/12.1 MB 24.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 160.5/160.5 kB 8.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 258.0/258.0 kB 13.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.9/81.9 kB 6.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 12.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.9/79.9 MB 8.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.8/106.8 kB 9.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.7/80.7 kB 5.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.9/21.9 MB 33.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.0/44.0 kB 3.8 MB/s eta 0:00:00
# ...

# %% [markdown]
# #2.Выполните импорт всех библиотек из модуля classification библиотеки pycaret

# %%
from pycaret.datasets import get_data
diabetes_data = get_data('diabetes')
print(diabetes_data.head())
# Out:
#    Number of times pregnant  \
# 0                         6
# 1                         1
# 2                         8
# 3                         1
# 4                         0
#
#    Plasma glucose concentration a 2 hours in an oral glucose tolerance test  \
# 0                                                148
# 1                                                 85
# 2                                                183
# 3                                                 89
# 4                                                137
#
#    Diastolic blood pressure (mm Hg)  Triceps skin fold thickness (mm)  \
# 0                                72                                35
# 1                                66                                29
# 2                                64                                 0
# 3                                66                                23
# 4                                40                                35
#
# ...

# %% [markdown]
# #3.Настройте эксперимент, цель - значения столбца 'Class variable'

# %%
from pycaret.classification import *

export = setup(data=diabetes_data, target='Class variable')
# Out:
# <style type="text/css">
# #T_159a6_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_159a6" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_159a6_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_159a6_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_159a6_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_159a6_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_159a6_row0_col1" class="data row0 col1" >7067</td>
#     </tr>
#     <tr>
#       <th id="T_159a6_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_159a6_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_159a6_row1_col1" class="data row1 col1" >Class variable</td>
#     </tr>
#     <tr>
#       <th id="T_159a6_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %% [markdown]
# #4.Выполните поиск наилучшей модели

# %%
bestModel = compare_models()
# Out:
# <style type="text/css">
# #T_413c7 th {
#   text-align: left;
# }
# ...

# %% [markdown]
# #5.Определите наиболее значимые признаки

# %%
plot_model(bestModel, plot='feature')

# %% [markdown]
# #6.Выполните графическое построение наилучшей модели

# %%
plot_model(bestModel, plot='confusion_matrix')
plot_model(bestModel, plot='learning')
